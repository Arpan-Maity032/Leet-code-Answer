# %%
import numpy as np
import pandas as pd
# Out:
# C:\Users\arpan\AppData\Local\Temp\ipykernel_9252\1662815981.py:2: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
data=pd.read_csv("C:\\Users\\arpan\\Downloads\\Online_Retail\\Online_Retail_Test.csv")
data.head(10)
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    555200     71459       HANGING JAM JAR T-LIGHT HOLDER        24
# 1    554974     21128                   GOLD FISHING GNOME         4
# 2    550972     21086          SET/6 RED SPOTTY PAPER CUPS         4
# 3    576652     22812     PACK 3 BOXES CHRISTMAS PANETTONE         3
# 4    546157     22180                       RETROSPOT LAMP         2
# 5    576200     82482    WOODEN PICTURE FRAME WHITE FINISH         2
# 6    577076     22614          PACK OF 12 SPACEBOY TISSUES        12
# 7    568909     22596  CHRISTMAS STAR WISH LIST CHALKBOARD        12
# 8    578072     21109     LARGE CAKE TOWEL CHOCOLATE SPOTS         1
# 9    560491     23297  SET 40 HEART SHAPE PETIT FOUR CASES         2
#
#            InvoiceDate  UnitPrice  CustomerID         Country
# 0  2011-06-01 12:05:00       0.85     17315.0  United Kingdom
# 1  2011-05-27 17:14:00       6.95     14031.0  United Kingdom
# ...

# %%
x=data["Quantity"]
x
# Out:
# 0        24
# 1         4
# 2         4
# 3         3
# 4         2
#          ..
# 27091     1
# 27092     9
# 27093     1
# 27094    24
# 27095     5
# Name: Quantity, Length: 27096, dtype: int64

# %%
z=x,data["UnitPrice"],data["CustomerID"]

# %%
z
# Out:
# (0        24
#  1         4
#  2         4
#  3         3
#  4         2
#           ..
#  27091     1
#  27092     9
#  27093     1
#  27094    24
#  27095     5
#  Name: Quantity, Length: 27096, dtype: int64,
#  0         0.85
#  1         6.95
#  2         0.65
#  3         1.95
#  4         9.95
#           ...
#  27091    10.79
#  27092     1.63
#  27093     0.83
#  27094     0.55
#  27095     1.65
#  Name: UnitPrice, Length: 27096, dtype: float64,
#  0        17315.0
#  1        14031.0
#  2        14031.0
#  3        17198.0
#  4        13502.0
#            ...
#  27091        NaN
#  27092        NaN
#  27093        NaN
#  27094    16062.0
#  27095    12867.0
#  Name: CustomerID, Length: 27096, dtype: float64)

# %%
df=pd.DataFrame(z)
df=df.transpose()
df
# Out:
#        Quantity  UnitPrice  CustomerID
# 0          24.0       0.85     17315.0
# 1           4.0       6.95     14031.0
# 2           4.0       0.65     14031.0
# 3           3.0       1.95     17198.0
# 4           2.0       9.95     13502.0
# ...         ...        ...         ...
# 27091       1.0      10.79         NaN
# 27092       9.0       1.63         NaN
# 27093       1.0       0.83         NaN
# 27094      24.0       0.55     16062.0
# 27095       5.0       1.65     12867.0
#
# [27096 rows x 3 columns]

# %%
df.fillna("0",inplace=True)
# Out:
# C:\Users\arpan\AppData\Local\Temp\ipykernel_9252\1045650231.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.fillna("0",inplace=True)

# %%
import seaborn as sns

# %%
sns.set_theme()

# %%
sns.relplot(data=df,y="UnitPrice",x="Quantity",kind="line",
     
    )

# %%
data=sns.load_dataset("anagrams")

# %%
data
# Out:
#     subidr    attnr  num1  num2  num3
# 0        1  divided     2   4.0     7
# 1        2  divided     3   4.0     5
# 2        3  divided     3   5.0     6
# 3        4  divided     5   7.0     5
# 4        5  divided     4   5.0     8
# 5        6  divided     5   5.0     6
# 6        7  divided     5   4.5     6
# 7        8  divided     5   7.0     8
# 8        9  divided     2   3.0     7
# 9       10  divided     6   5.0     6
# 10      11  focused     6   5.0     6
# 11      12  focused     8   9.0     8
# 12      13  focused     6   5.0     9
# 13      14  focused     8   8.0     7
# 14      15  focused     8   8.0     7
# 15      16  focused     6   8.0     7
# 16      17  focused     7   7.0     6
# 17      18  focused     7   8.0     6
# 18      19  focused     5   6.0     6
# 19      20  focused     6   6.0     5

# %%
sns.catplot(data=data,x="num1",y="num3",kind="violin",hue="attnr",)

# %%
df1=sns.load_dataset("penguins")

# %%
df1
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
sns.jointplot(data=df1,x="bill_length_mm",y="bill_depth_mm",hue="sex")

# %%
sns.pairplot(data=df1,hue="sex")
